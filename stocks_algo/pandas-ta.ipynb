# %%
import pandas_ta as ta 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()
df = df.ta.ticker("AAPL", period="1y")
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-12-27 00:00:00-05:00  176.068149  179.378936  176.048276  179.289459
# 2021-12-28 00:00:00-05:00  179.120438  180.283685  177.499838  178.255447
# 2021-12-29 00:00:00-05:00  178.295226  179.587727  177.112090  178.344940
# 2021-12-30 00:00:00-05:00  178.434398  179.528057  177.062357  177.171722
# 2021-12-31 00:00:00-05:00  177.062383  178.195805  176.237171  176.545395
# ...                               ...         ...         ...         ...
# 2022-12-19 00:00:00-05:00  135.110001  135.199997  131.320007  132.369995
# 2022-12-20 00:00:00-05:00  131.389999  133.250000  129.889999  132.300003
# 2022-12-21 00:00:00-05:00  132.979996  136.809998  132.750000  135.449997
# 2022-12-22 00:00:00-05:00  134.350006  134.559998  130.300003  132.229996
# 2022-12-23 00:00:00-05:00  130.919998  132.419998  129.639999  131.860001
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
df.ta.indicators()
df.ta.categories
# Out:
# Pandas TA - Technical Analysis Indicators - v0.3.14b0
# Total Indicators & Utilities: 205
# Abbreviations:
# ...

# %%
df = df.ta.ticker("RELIANCE.NS", period="1y")
CustomStrategy = ta.Strategy(
    name="CustomStrategy",
    description="A custom strategy using the Strategy class.",
    ta=[
        {"kind": "sma", "length": 50},
        {"kind": "sma", "length": 100},
        {"kind": "rsi", "length": 14},
        {"kind": "macd", "fast": 12, "slow": 26, "signal": 9},
        {"kind": "bbands", "length": 20, "std": 2},
    ]
)

df.ta.strategy(CustomStrategy)
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2021-12-27 00:00:00+05:30  2354.461417  2370.861991  2341.051839  2363.135254
# 2021-12-28 00:00:00+05:30  2368.469317  2397.631518  2365.926922  2391.200684
# 2021-12-29 00:00:00+05:30  2383.822850  2411.738801  2374.949663  2395.288330
# 2021-12-30 00:00:00+05:30  2392.795932  2397.731025  2338.559322  2352.018799
# 2021-12-31 00:00:00+05:30  2365.877043  2376.744228  2352.916065  2361.041504
# ...                                ...          ...          ...          ...
# 2022-12-21 00:00:00+05:30  2621.000000  2633.000000  2576.100098  2584.500000
# 2022-12-22 00:00:00+05:30  2598.000000  2604.649902  2566.750000  2577.800049
# 2022-12-23 00:00:00+05:30  2563.300049  2590.500000  2492.250000  2502.199951
# 2022-12-26 00:00:00+05:30  2514.750000  2542.000000  2492.399902  2524.050049
# 2022-12-27 00:00:00+05:30  2530.000000  2548.800049  2515.250000  2544.699951
#
# ...

# %%
stock = input("Enter the stock ticker: ")
period = input("Enter the period: ")
df = pd.DataFrame()
df = df.ta.ticker(stock, period=period)

print("These are the following categories of indicators:")
print(df.ta.categories)

input1 = input("Enter the category of indicators you want to see: ")

cat_list = input1.split(",")
for i in cat_list:
    df.ta.strategy(i)

df
# Out:
# These are the following categories of indicators:
# ['candles', 'cycles', 'momentum', 'overlap', 'performance', 'statistics', 'trend', 'volatility', 'volume']
#                                   Open         High          Low        Close  \
# Date
# 2022-11-28 00:00:00+05:30  2064.350098  2072.000000  2052.000000  2064.449951
# 2022-11-29 00:00:00+05:30  2070.000000  2072.000000  2038.599976  2050.550049
# 2022-11-30 00:00:00+05:30  2053.000000  2086.000000  2045.000000  2074.850098
# 2022-12-01 00:00:00+05:30  2085.250000  2110.000000  2079.449951  2104.250000
# 2022-12-02 00:00:00+05:30  2096.100098  2098.899902  2069.149902  2085.500000
# 2022-12-05 00:00:00+05:30  2095.949951  2096.800049  2068.850098  2085.600098
# 2022-12-06 00:00:00+05:30  2081.000000  2100.000000  2067.000000  2093.500000
# 2022-12-07 00:00:00+05:30  2096.300049  2144.000000  2096.300049  2124.000000
# 2022-12-08 00:00:00+05:30  2120.000000  2175.000000  2120.000000  2167.699951
# ...

# %%
df.ta.exchange
df.ta.exchange = "NSE"

# %%
df.ta.last_run
# Out:
# 'Tuesday December 20, 2022, NYSE: 15:06:50, Local: 19:06:50 IST, Day 354/365 (97.00%)'

# %%
df.ta.time_range
df.ta.time_range = "days"

# %%
help(ta.yf)
# Out:
# Help on function yf in module pandas_ta.utils.data.yahoofinance:
#
# yf(ticker: str, **kwargs)
#     yf - yfinance wrapper
#
#     It retrieves market data (ohlcv) from Yahoo Finance using yfinance.
#     To install yfinance. (pip install yfinance) This method can also pull
#     additional data using the 'kind' kwarg. By default kind=None and retrieves
#     Historical Chart Data.
#
#     Other options of 'kind' include:
#     * All: "all"
#         - Prints everything below but only returns Chart History to Pandas TA
#     * Company Information: "info"
#     * Institutional Holders: "institutional_holders" or "ih"
#     * Major Holders: "major_holders" or "mh"
#     * Mutual Fund Holders: "mutualfund_holders" or "mfh"
#     * Recommendations (YTD): "recommendations" or "rec"
#     * Earnings Calendar: "calendar" or "cal"
#     * Earnings: "earnings" or "earn"
#     * Sustainability/ESG Scores: "sustainability", "sus" or "esg"
#     * Financials: "financials" or "fin"
# ...

# %%
rel = ta.yahoofinance.yf("LT.NS", period="1y", interval="1d")
rel
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2021-12-27 00:00:00+05:30  1835.889690  1851.934224  1822.461673  1842.603638
# 2021-12-28 00:00:00+05:30  1848.429088  1884.862548  1848.429088  1875.482666
# 2021-12-29 00:00:00+05:30  1871.039485  1884.813052  1866.152121  1870.891357
# 2021-12-30 00:00:00+05:30  1868.373701  1877.654751  1857.117819  1861.857056
# 2021-12-31 00:00:00+05:30  1863.486281  1882.986561  1863.436985  1871.928223
# ...                                ...          ...          ...          ...
# 2022-12-21 00:00:00+05:30  2153.100098  2174.949951  2142.850098  2146.300049
# 2022-12-22 00:00:00+05:30  2144.000000  2148.350098  2096.899902  2109.949951
# 2022-12-23 00:00:00+05:30  2094.500000  2104.149902  2050.100098  2062.750000
# 2022-12-26 00:00:00+05:30  2052.750000  2108.000000  2051.000000  2091.050049
# 2022-12-27 00:00:00+05:30  2101.550049  2128.000000  2085.000000  2124.100098
#
# ...

# %%
df = pd.DataFrame()
df = df.ta.ticker("LT.NS", period="1y", exchange="NSE")
df.ta.strategy("trend")
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2021-12-27 00:00:00+05:30  1835.889690  1851.934224  1822.461673  1842.603638
# 2021-12-28 00:00:00+05:30  1848.429088  1884.862548  1848.429088  1875.482666
# 2021-12-29 00:00:00+05:30  1871.039485  1884.813052  1866.152121  1870.891357
# 2021-12-30 00:00:00+05:30  1868.373701  1877.654751  1857.117819  1861.857056
# 2021-12-31 00:00:00+05:30  1863.486281  1882.986561  1863.436985  1871.928223
# ...                                ...          ...          ...          ...
# 2022-12-21 00:00:00+05:30  2153.100098  2174.949951  2142.850098  2146.300049
# 2022-12-22 00:00:00+05:30  2144.000000  2148.350098  2096.899902  2109.949951
# 2022-12-23 00:00:00+05:30  2094.500000  2104.149902  2050.100098  2062.750000
# 2022-12-26 00:00:00+05:30  2052.750000  2108.000000  2051.000000  2091.050049
# 2022-12-27 00:00:00+05:30  2101.550049  2128.000000  2085.000000  2124.100098
#
# ...
