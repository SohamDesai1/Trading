# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
import plotly.graph_objects as go

# %%
url = "https://groww.in/v1/api/stocks_data/v1/tr_live_prices/exchange/NSE/segment/CASH/LT/latest"
candles = requests.get(url).json()
print(candles)
# Out:
# {'type': 'LIVE_PRICE', 'symbol': 'LT', 'open': 2144, 'high': 2148.35, 'low': 2096.9, 'close': 2146.3, 'ltp': 2107.1, 'volume': 1516029, 'tsInMillis': 1671698515, 'lowPriceRange': 1931.7, 'highPriceRange': 2360.9, 'totalBuyQty': 116087, 'totalSellQty': 294145, 'dayChange': -39.20000000000027, 'dayChangePerc': -1.82639891907004, 'openInterest': None, 'lastTradeQty': 6, 'lastTradeTime': 1671678715, 'prevOpenInterest': None, 'oiDayChange': 0, 'oiDayChangePerc': 0}

# %%
url = "https://groww.in/v1/api/charting_service/v2/chart/exchange/NSE/segment/CASH/RELIANCE/daily?intervalInMinutes=30&startDate=2022-11-24&endDate=2022-11-25"
price = requests.get(url).json()
prices = pd.DataFrame(price)
print(price)
# Out:
# {'candles': [[1671680700, 2598.0, 2604.5, 2575.5, 2585.45, 607255], [1671682500, 2584.25, 2599.0, 2582.2, 2583.1, 840804], [1671684300, 2582.4, 2589.7, 2578.0, 2583.0, 1082985], [1671686100, 2583.55, 2590.5, 2579.5, 2586.15, 1365729], [1671687900, 2586.85, 2587.0, 2568.9, 2569.35, 1600952], [1671689700, 2568.9, 2577.2, 2566.9, 2574.25, 1774778], [1671691500, 2574.4, 2579.8, 2570.6, 2571.2, 1895108], [1671693300, 2570.8, 2579.75, 2568.05, 2576.9, 2036366], [1671695100, 2577.55, 2587.35, 2576.3, 2585.2, 2247003], [1671696900, 2585.7, 2593.15, 2584.15, 2587.5, 2514409], [1671698700, 2587.25, 2587.9, 2587.0, 2587.75, 2515054]], 'changeValue': None, 'changePerc': None, 'closingPrice': None, 'startTimeEpochInMillis': 0}

# %%
url = "https://groww.in/v1/api/charting_service/v2/chart/exchange/NSE/segment/CASH/LICI/daily?intervalInMinutes=2"
price = requests.get(url).json()

prices = pd.DataFrame(price['candles'])

prices.columns = ['date', 'open', 'high', 'low', 'close', 'volume']

prices['date'] = pd.to_datetime(prices['date'], unit='s')

prices['date'] = prices['date'] + pd.DateOffset(hours=5, minutes=30)

prices.set_index('date', inplace=True)
print(prices)
fig = go.Figure(data=[go.Candlestick(x=prices.index, open=prices['open'], high=prices['high'], low=prices['low'], close=prices['close'])])
fig.update_xaxes(rangeslider_visible=False)  
fig.show()
# Out:
#                        open    high     low   close   volume
# date
# 2022-12-22 09:15:00  705.20  712.00  705.20  708.80   147846
# 2022-12-22 09:17:00  708.50  713.50  708.50  712.00   250377
# 2022-12-22 09:19:00  713.00  713.40  710.50  710.65   324820
# 2022-12-22 09:21:00  711.00  711.45  709.45  710.10   369025
# 2022-12-22 09:23:00  710.15  710.45  707.10  707.55   411541
# ...                     ...     ...     ...     ...      ...
# 2022-12-22 14:33:00  684.05  684.50  683.90  684.30  3473287
# 2022-12-22 14:35:00  684.10  684.50  683.10  683.40  3484496
# 2022-12-22 14:37:00  683.10  684.35  682.95  684.35  3498077
# 2022-12-22 14:39:00  684.10  684.50  681.95  681.95  3519728
# 2022-12-22 14:41:00  682.25  682.25  681.00  681.55  3543538
#
# [164 rows x 5 columns]

# %%
url = "https://groww.in/v1/api/stocks_data/explore/v2/indices/GIDXNIFTY100/market_trends?discovery_filter_types=TOP_GAINERS&size=20"
data = requests.get(url).json()
# print(data)
Company =[]
Symbol =[]
Prices = []
for i in range(0,len(data['categoryResponseMap']['TOP_GAINERS']['items'])):
    company = data['categoryResponseMap']['TOP_GAINERS']['items'][i]['company']['companyName']
    symbol = data['categoryResponseMap']['TOP_GAINERS']['items'][i]['company']['nseScriptCode']
    closing = data['categoryResponseMap']['TOP_GAINERS']['items'][i]['stats']['close']
    Company.append(company)
    Symbol.append(symbol)
    Prices.append(closing)
Top_Gainers = pd.DataFrame(data={"Stock":Company,"Symbol":Symbol})
stats_list = []
for item in data["categoryResponseMap"]["TOP_GAINERS"]["items"]:
    stats_list.append(item["stats"])
df = pd.DataFrame(stats_list)
Top_Gainers = pd.concat([Top_Gainers,df],axis=1)
print(Top_Gainers)
# Out:
#                                          Stock      Symbol       ltp  \
# 0                          Mahindra & Mahindra         M&M   1552.05
# 1                  Apollo Hospitals Enterprise  APOLLOHOSP   5297.60
# 2                                   Coal India   COALINDIA    323.55
# 3                                PI Industries       PIIND   3647.85
# 4                            Info Edge (India)      NAUKRI   4569.10
# 5                     Steel Authority of India        SAIL     87.15
# 6              Power Grid Corporation of India   POWERGRID    209.80
# 7                                Hero MotoCorp  HEROMOTOCO   3173.90
# 8                                IndusInd Bank  INDUSINDBK   1507.35
# 9                      Torrent Pharmaceuticals  TORNTPHARM   2051.20
# 10                                 Tata Motors  TATAMOTORS    649.35
# 11                           Avenue Supermarts       DMART   3747.60
# 12                             Larsen & Toubro          LT   3024.85
# 13                                   ABB India         ABB   4310.50
# 14                                         DLF         DLF    600.70
# 15  Cholamandalam Investment & Finance Company    CHOLAFIN   1152.05
# 16                         Maruti Suzuki India      MARUTI  10400.35
# 17               HDFC Asset Management Company     HDFCAMC   2762.50
# 18                                        NTPC        NTPC    237.95
# 19                                  Tata Steel   TATASTEEL    119.65
#
#        close  dayChange  dayChangePerc      high       low  yearHighPrice  \
# 0    1487.40      64.65       4.346511   1558.70   1487.40        1670.00
# 1    5110.95     186.65       3.651963   5313.00   5122.05        5364.00
# 2     317.40       6.15       1.937618    324.50    315.70         319.75
# 3    3579.10      68.75       1.920874   3737.50   3555.00        4011.15
# 4    4505.80      63.30       1.404856   4602.85   4456.10        4984.50
# 5      85.95       1.20       1.396161     87.50     86.00         103.65
# 6     207.00       2.80       1.352657    210.50    206.10         209.60
# 7    3132.10      41.80       1.334568   3196.00   3135.00        3275.00
# 8    1488.95      18.40       1.235770   1516.30   1484.85        1495.95
# 9    2028.10      23.10       1.138997   2059.90   2016.90        2094.55
# 10    642.55       6.80       1.058283    653.65    642.70         677.80
# 11   3712.40      35.20       0.948174   3765.00   3725.00        4228.95
# 12   2996.45      28.40       0.947788   3028.70   2997.00        3114.95
# 13   4275.55      34.95       0.817439   4372.95   4216.00        4678.00
# 14    595.90       4.80       0.805504    605.60    596.95         601.40
# 15   1143.15       8.90       0.778550   1155.85   1135.25        1272.90
# 16  10322.30      78.05       0.756130  10449.60  10316.75       10845.00
# 17   2745.95      16.55       0.602706   2765.55   2724.75        2930.00
# 18    236.70       1.25       0.528095    239.70    236.00         251.50
# 19    119.05       0.60       0.503990    120.50    118.85         135.00
#
#     yearLowPrice      lpr       upr
# 0        1123.40  1338.70   1636.10
# 1        4123.00  4599.85   5622.00
# 2         207.60   285.70    349.10
# 3        2868.90  3221.20   3937.00
# 4        3308.20  4055.25   4956.35
# 5          73.75    77.35     94.50
# 6         153.19   186.30    227.70
# 7        2246.00  2818.90   3445.30
# 8         990.00  1340.05   1637.80
# 9        1445.55  1825.30   2230.90
# 10        375.20   578.30    706.80
# 11       3292.00  2969.95   4454.85
# 12       1970.20  2696.80   3296.05
# 13       2640.00  3848.00   4703.10
# 14        336.50   536.35    655.45
# 15        658.00  1028.85   1257.45
# 16       8076.05  9290.10  11354.50
# 17       1589.50  2471.35   3020.50
# 18        161.90   213.05    260.35
# 19        101.55   107.15    130.95

# %%
url = "https://groww.in/v1/api/stocks_data/explore/v2/indices/GIDXNIFTY100/market_trends?discovery_filter_types=TOP_LOSERS&size=20"
data = requests.get(url).json()
Company = []
Symbol = []
Prices = []
for i in range(0,len(data['categoryResponseMap']['TOP_LOSERS']['items'])):
    company = data['categoryResponseMap']['TOP_LOSERS']['items'][i]['company']['companyName']
    symbol = data['categoryResponseMap']['TOP_LOSERS']['items'][i]['company']['nseScriptCode']
    closing = data['categoryResponseMap']['TOP_LOSERS']['items'][i]['stats']['close']
    Company.append(company)
    Symbol.append(symbol)
    Prices.append(closing)
Top_Losers = pd.DataFrame(data={"Stock":Company,"Symbol":Symbol,"Closing Price":Prices})
stats_list = []
for item in data["categoryResponseMap"]["TOP_LOSERS"]["items"]:
    stats_list.append(item["stats"])
df = pd.DataFrame(stats_list)
Top_Losers = pd.concat([Top_Losers,df],axis=1)
print(Top_Losers)
# Out:
#                                      Stock      Symbol  Closing Price  \
# 0                 Godrej Consumer Products    GODREJCP        1015.50
# 1                                   Zomato      ZOMATO         125.15
# 2                       Zydus Lifesciences   ZYDUSLIFE         625.20
# 3                        Adani Enterprises    ADANIENT        2259.95
# 4   Procter & Gamble Hygiene & Health Care        PGHH       17570.05
# 5                             Adani Wilmar         AWL         306.15
# 6                       Hindustan Unilever  HINDUNILVR        2519.35
# 7      Adani Ports & Special Economic Zone  ADANIPORTS         818.70
