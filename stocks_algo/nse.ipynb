# %%
import nselib as nse
from nselib import capital_market

# %%
nse.trading_holiday_calendar()
# Out:
#                                    Product  tradingDate    weekDay  \
# 0                          Corporate Bonds  26-Jan-2023   Thursday
# 1                          Corporate Bonds  18-Feb-2023   Saturday
# 2                          Corporate Bonds  19-Feb-2023     Sunday
# 3                          Corporate Bonds  07-Mar-2023    Tuesday
# 4                          Corporate Bonds  22-Mar-2023  Wednesday
# ..                                     ...          ...        ...
# 14  Securities Lending & Borrowing Schemes  24-Oct-2023    Tuesday
# 15  Securities Lending & Borrowing Schemes  12-Nov-2023     Sunday
# 16  Securities Lending & Borrowing Schemes  14-Nov-2023    Tuesday
# 17  Securities Lending & Borrowing Schemes  27-Nov-2023     Monday
# 18  Securities Lending & Borrowing Schemes  25-Dec-2023     Monday
#
#                              description Sr_no
# 0                         Republic Day\r     1
# 1                        Mahashivratri\r     2
# ...

# %%
capital_market.bhav_copy_equities(trade_date="29-12-2023")
# Out:
#           SYMBOL SERIES     OPEN     HIGH      LOW    CLOSE     LAST  \
# 0     182D040124     TB    99.90    99.90    99.90    99.90    99.90
# 1     182D060624     TB    96.98    96.98    96.97    96.97    96.97
# 2     182D080224     TB    99.25    99.25    99.19    99.19    99.19
# 3     182D130624     TB    96.78    96.78    96.78    96.78    96.78
# 4     182D180124     TB    99.52    99.52    99.52    99.52    99.52
# ...          ...    ...      ...      ...      ...      ...      ...
# 2642        ZOTA     EQ   481.45   483.00   468.35   472.45   471.00
# 2643       ZUARI     EQ   184.00   192.00   182.20   188.95   188.15
# 2644    ZUARIIND     EQ   198.00   203.90   195.05   197.35   198.00
# 2645   ZYDUSLIFE     EQ   687.95   691.80   683.35   689.20   688.75
# 2646   ZYDUSWELL     EQ  1675.00  1706.15  1663.40  1681.10  1673.95
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES
# 0         99.75       2000  1.998000e+05  29-DEC-2023            1
# ...

# %%
capital_market.block_deals_data(period='1M')
# Out:
#     Date      Symbol            SecurityName  \
# 0    NaN  BHARTIARTL   Bharti Airtel Limited
# 1    NaN  BHARTIARTL   Bharti Airtel Limited
# 2    NaN         HCC  Hindustan Construc Co.
# 3    NaN         HCC  Hindustan Construc Co.
# 4    NaN        SJVN                SJVN Ltd
# ..   ...         ...                     ...
# 203  NaN   ZYDUSWELL  Zydus Wellness Limited
# 204  NaN   DALBHARAT   Dalmia Bharat Limited
# 205  NaN   DALBHARAT   Dalmia Bharat Limited
# 206  NaN    RAMCOIND    Ramco Industries Ltd
# 207  NaN    RAMCOIND    Ramco Industries Ltd
#
#                               ClientName Buy/Sell QuantityTraded  \
# 0                 BHARTI TELECOM LIMITED      BUY    8,11,50,803
# 1    INDIAN CONTINENT INVESTMENT LIMITED     SELL    8,11,50,803
# 2                 BLACKROCK GLOBAL FUNDS      BUY      60,00,000
# 3                  BNP PARIBAS ARBITRAGE     SELL      60,00,000
# 4                 BLACKROCK GLOBAL FUNDS      BUY      50,00,000
# ...

# %%
capital_market.deliverable_position_data(symbol="REL",period='1M')
# Out:
#    Symbol Series         Date TradedQty DeliverableQty %DlyQttoTradedQty  \
# 0     NaN     EQ  30-Nov-2023       NaN            NaN               NaN
# 1     NaN     EQ  01-Dec-2023       NaN            NaN               NaN
# 2     NaN     EQ  04-Dec-2023       NaN            NaN               NaN
# 3     NaN     EQ  05-Dec-2023       NaN            NaN               NaN
# 4     NaN     EQ  06-Dec-2023       NaN            NaN               NaN
# 5     NaN     EQ  07-Dec-2023       NaN            NaN               NaN
# 6     NaN     EQ  08-Dec-2023       NaN            NaN               NaN
# 7     NaN     EQ  11-Dec-2023       NaN            NaN               NaN
# 8     NaN     EQ  12-Dec-2023       NaN            NaN               NaN
# 9     NaN     EQ  13-Dec-2023       NaN            NaN               NaN
# 10    NaN     EQ  14-Dec-2023       NaN            NaN               NaN
# 11    NaN     EQ  15-Dec-2023       NaN            NaN               NaN
# ...

# %%
capital_market.market_watch_all_indices()
# Out:
#                      key                                      index  \
# 0   BROAD MARKET INDICES                                   NIFTY 50
# 1   BROAD MARKET INDICES                              NIFTY NEXT 50
# 2   BROAD MARKET INDICES                                  NIFTY 100
# 3   BROAD MARKET INDICES                                  NIFTY 200
# 4   BROAD MARKET INDICES                                  NIFTY 500
# ..                   ...                                        ...
# 66  FIXED INCOME INDICES  NIFTY 10 YR BENCHMARK G-SEC (CLEAN PRICE)
# 67  FIXED INCOME INDICES                   NIFTY 4-8 YR G-SEC INDEX
# 68  FIXED INCOME INDICES                 NIFTY 11-15 YR G-SEC INDEX
# 69  FIXED INCOME INDICES          NIFTY 15 YR AND ABOVE G-SEC INDEX
# 70  FIXED INCOME INDICES                NIFTY COMPOSITE G-SEC INDEX
#
#           indexSymbol      last  variation  percentChange      open      high  \
# ...
