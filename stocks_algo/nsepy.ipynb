# %%
import nsepy as nse
from datetime import date

# %%
start = date(2022,12,26)
end = date.today()
stock = nse.get_history("RELIANCE",start=start,end=end)
stock.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
stock
# Out:
#               Symbol Series  Prev Close     Open    High     Low    Last  \
# Date
# 2022-12-26  RELIANCE     EQ      2502.2  2514.75  2542.0  2492.4  2525.0
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2022-12-26  2524.05  2523.81  2764496  6.977059e+14  117927
#
#             Deliverable Volume  %Deliverble
# Date
# 2022-12-26             1225057       0.4431

# %%
stocks = nse.get_quote("LT")
stocks
# Out:
# {'tradedDate': '27DEC2022',
#  'data': [{'pricebandupper': '2,300.15',
#    'symbol': 'LT',
#    'applicableMargin': '13.43',
#    'bcEndDate': '-',
#    'totalSellQuantity': '-',
#    'adhocMargin': '-',
#    'companyName': 'Larsen & Toubro Limited',
#    'marketType': 'N',
#    'exDate': '21-JUL-22',
#    'bcStartDate': '-',
#    'css_status_desc': 'Listed',
#    'dayHigh': '2,128.00',
#    'basePrice': '2,091.05',
#    'securityVar': '9.93',
#    'pricebandlower': '1,881.95',
#    'sellQuantity5': '-',
#    'sellQuantity4': '-',
#    'sellQuantity3': '-',
#    'cm_adj_high_dt': '16-DEC-22',
#    'sellQuantity2': '-',
#    'dayLow': '2,085.00',
#    'sellQuantity1': '-',
#    'quantityTraded': '10,59,351',
#    'pChange': '1.43',
#    'totalTradedValue': '22,363.22',
#    'deliveryToTradedQuantity': '50.58',
#    'totalBuyQuantity': '209',
#    'averagePrice': '2,111.03',
#    'indexVar': '-',
#    'cm_ffm': '2,56,689.93',
#    'purpose': 'DIVIDEND - RS 22 PER SHARE',
# ...

# %%
# options
rel = nse.get_history(symbol="RELIANCE", start=date(2022,12,1), end=date(2022,12,30), index=False,option_type="CE", strike_price=2100, expiry_date=date(2022,12,29))
rel
# Out:
#               Symbol      Expiry Option Type  Strike Price   Open   High  \
# Date
# 2022-12-01  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-02  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-05  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-06  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-07  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-08  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-09  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-12  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-13  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-14  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-15  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# 2022-12-16  RELIANCE  2022-12-29          CE        2100.0    0.0    0.0
# ...
