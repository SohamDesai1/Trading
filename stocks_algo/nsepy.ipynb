# %%
import nsepy as nse
from datetime import date

# %%
start = date(2022,12,7)
end = date.today()
stock = nse.get_history("RELIANCE",start=start,end=end)
stock.columns

# %%
stock
# Out:
#               Symbol Series  Prev Close    Open    High      Low    Last  \
# Date
# 2022-12-07  RELIANCE     EQ      2690.2  2685.0  2695.0  2642.15  2647.0
# 2022-12-08  RELIANCE     EQ      2650.5  2660.0  2665.0  2640.10  2649.0
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2022-12-07  2650.50  2665.31  3905263  1.040874e+15  158784
# 2022-12-08  2649.25  2651.78  3579858  9.492988e+14  144130
#
#             Deliverable Volume  %Deliverble
# Date
# 2022-12-07             2425575       0.6211
# 2022-12-08             2190085       0.6118

# %%
stocks = nse.get_quote("LT")
stocks
# Out:
# {'tradedDate': '08DEC2022',
#  'data': [{'pricebandupper': '2,336.40',
#    'symbol': 'LT',
#    'applicableMargin': '13.59',
#    'bcEndDate': '-',
#    'totalSellQuantity': '-',
#    'adhocMargin': '-',
#    'companyName': 'Larsen & Toubro Limited',
#    'marketType': 'N',
#    'exDate': '21-JUL-22',
#    'bcStartDate': '-',
#    'css_status_desc': 'Listed',
#    'dayHigh': '2,175.00',
#    'basePrice': '2,124.00',
#    'securityVar': '10.09',
#    'pricebandlower': '1,911.60',
#    'sellQuantity5': '-',
#    'sellQuantity4': '-',
#    'sellQuantity3': '-',
#    'cm_adj_high_dt': '08-DEC-22',
#    'sellQuantity2': '-',
#    'dayLow': '2,120.00',
#    'sellQuantity1': '-',
#    'quantityTraded': '37,43,754',
#    'pChange': '1.93',
#    'totalTradedValue': '80,547.99',
#    'deliveryToTradedQuantity': '69.37',
#    'totalBuyQuantity': '2',
#    'averagePrice': '2,151.53',
#    'indexVar': '-',
#    'cm_ffm': '2,61,958.83',
#    'purpose': 'DIVIDEND - RS 22 PER SHARE',
#    'buyPrice2': '-',
#    'secDate': '08-Dec-2022 00:00:00',
#    'buyPrice1': '2,167.70',
#    'high52': '2,175.00',
#    'previousClose': '2,124.00',
#    'ndEndDate': '-',
#    'low52': '1,456.35',
#    'buyPrice4': '-',
#    'buyPrice3': '-',
#    'recordDate': '22-JUL-22',
#    'deliveryQuantity': '25,96,859',
#    'buyPrice5': '-',
#    'priceBand': 'No Band',
#    'extremeLossMargin': '3.50',
#    'cm_adj_low_dt': '20-JUN-22',
#    'varMargin': '10.09',
#    'sellPrice1': '-',
#    'sellPrice2': '-',
#    'totalTradedVolume': '37,43,754',
#    'sellPrice3': '-',
#    'sellPrice4': '-',
#    'sellPrice5': '-',
#    'change': '41.00',
#    'surv_indicator': '-',
#    'ndStartDate': '-',
#    'buyQuantity4': '-',
#    'isExDateFlag': False,
#    'buyQuantity3': '-',
#    'buyQuantity2': '-',
#    'buyQuantity1': '2',
#    'series': 'EQ',
#    'faceValue': '2.00',
#    'buyQuantity5': '-',
#    'closePrice': '2,167.70',
#    'open': '2,120.00',
#    'isinCode': 'INE018A01030',
#    'lastPrice': '2,165.00'}],
#  'optLink': '/marketinfo/sym_map/symbolMapping.jsp?symbol=LT&instrument=-&date=-&segmentLink=17&symbolCount=2',
#  'otherSeries': ['EQ'],
#  'futLink': '/live_market/dynaContent/live_watch/get_quote/GetQuoteFO.jsp?underlying=LT&instrument=FUTSTK&expiry=13DEC2022&type=-&strike=-',
#  'lastUpdateTime': '08-DEC-2022 16:00:18'}
